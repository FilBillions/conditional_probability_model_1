# %%
from datetime import date, timedelta
from conditional_probability_obj import Conditional_Probability
from current_given_previous_func import conditional_probability
from charts import comparison, visual, linear_regression, normal

# %%
# YYYY-MM-DD
# for current day: str(date.today() - timedelta(1))
# for 60 days ago for smaller timeframes: str(date.today() - timedelta(59))
# for 730 days ago for smaller timeframes: str(date.today() - timedelta(729))

# %%
test = Conditional_Probability("SPY", start = "2000-01-01", end=str(date.today() - timedelta(1)), interval = "1d")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
#target_probability, start_date, end_date
test.run_algo(target_probability=.55, start_date="2024-06-20", end_date="2025-06-20", print_table=True)
# Out:
#                Close      High       Low      Open    Volume  Day Count  \
# Date
# 2024-06-21  537.8115  538.9375  536.3399  537.7029  64513900       6156
# 2024-06-24  536.0632  540.2215  535.9447  537.6337  45528700       6157
# 2024-06-25  538.1276  538.4930  535.7670  537.2979  38273300       6158
# 2024-06-26  538.7992  539.5202  536.3497  537.0016  38550600       6159
# 2024-06-27  539.6486  540.2314  537.9103  538.6609  35041500       6160
# ...              ...       ...       ...       ...       ...        ...
# 2025-06-12  601.9704  601.9704  597.7529  598.2414  64129000       6400
# 2025-06-13  595.2403  600.0760  593.7248  596.7359  89506000       6401
# 2025-06-16  600.9036  602.6684  598.4508  598.6303  79984100       6402
# 2025-06-17  595.7688  599.9763  595.0010  598.4409  82209400       6403
# 2025-06-18  595.6790  599.4478  594.7118  596.6761  76605000       6404
#
#             Return  Previous Close     Action  Probability > 0%  Buy Signal  \
# Date
# 2024-06-21 -0.1341        538.5334  No Action            0.5383         NaN
# 2024-06-24 -0.3256        537.8115        Buy            0.5570    537.8115
# 2024-06-25  0.3844        536.0632       Hold            0.5570         NaN
# 2024-06-26  0.1247        538.1276       Hold            0.5570         NaN
# 2024-06-27  0.1575        538.7992       Sell            0.5383         NaN
# ...            ...             ...        ...               ...         ...
# 2025-06-12  0.3966        599.5875  No Action            0.5384         NaN
# 2025-06-13 -1.1243        601.9704        Buy            0.5602    601.9704
# 2025-06-16  0.9469        595.2403       Sell            0.5384         NaN
# 2025-06-17 -0.8582        600.9036  No Action            0.5495         NaN
# 2025-06-18 -0.0151        595.7688  No Action            0.5384         NaN
#
#             Sell Signal
# Date
# 2024-06-21          NaN
# 2024-06-24          NaN
# 2024-06-25          NaN
# 2024-06-26          NaN
# 2024-06-27     538.7992
# ...                 ...
# 2025-06-12          NaN
# 2025-06-13          NaN
# 2025-06-16     595.2403
# 2025-06-17          NaN
# 2025-06-18          NaN
#
# [249 rows x 12 columns]

# %%
test.backtest(print_table=True)
# Out:
# SPY Buy/Hold Result: 10.76%
# SPY Model Result: 21.58%
#  from 2024-06-21 00:00:00 to 2025-06-18 00:00:00
#                  Close        High         Low        Open  Day Count  \
# Date
# 2024-06-21  537.811523  538.937514  536.339863  537.702891       6156
# 2024-06-24  536.063232  540.221463  535.944713  537.633699       6157
# 2024-06-25  538.127563  538.493007  535.766951  537.297871       6158
# 2024-06-26  538.799194  539.520195  536.349722  537.001577       6159
# 2024-06-27  539.648621  540.231389  537.910262  538.660922       6160
# ...                ...         ...         ...         ...        ...
# 2025-06-12  601.970398  601.970398  597.752886  598.241432       6400
# 2025-06-13  595.240295  600.075975  593.724756  596.735874       6401
# 2025-06-16  600.903564  602.668367  598.450794  598.630317       6402
# 2025-06-17  595.768799  599.976331  595.001049  598.440892       6403
# 2025-06-18  595.679016  599.447843  594.711844  596.676069       6404
#
#               Return  Previous Close     Action  Probability > 0%  Buy Signal  \
# Date
# 2024-06-21 -0.134144      538.533447  No Action          0.538336         NaN
# 2024-06-24 -0.325605      537.811523        Buy          0.556968  537.811523
# 2024-06-25  0.384351      536.063232       Hold          0.556968         NaN
# 2024-06-26  0.124731      538.127563       Hold          0.556968         NaN
# 2024-06-27  0.157528      538.799194       Sell          0.538336         NaN
# ...              ...             ...        ...               ...         ...
# 2025-06-12  0.396641      599.587463  No Action          0.538432         NaN
# 2025-06-13 -1.124309      601.970398        Buy          0.560197  601.970398
# 2025-06-16  0.946928      595.240295       Sell          0.538402         NaN
# 2025-06-17 -0.858179      600.903564  No Action          0.549488         NaN
# 2025-06-18 -0.015071      595.768799  No Action          0.538402         NaN
#
#             Sell Signal  Buy/Hold Value   Model Value
# Date
# 2024-06-21          NaN     9986.594633  10000.000000
# 2024-06-24          NaN     9954.130707  10000.000000
# 2024-06-25          NaN     9992.463165   9967.492496
# 2024-06-26          NaN    10004.934644  10005.876409
# 2024-06-27   538.799194    10020.707597  10018.364629
# ...                 ...             ...           ...
# 2025-06-12          NaN    11177.957488  12295.441425
# 2025-06-13          NaN    11052.986559  12295.441425
# 2025-06-16   595.240295    11158.147512  12157.976889
# 2025-06-17          NaN    11062.800312  12157.976889
# 2025-06-18          NaN    11061.133141  12157.976889
#
# [249 rows x 13 columns]

# %%
test.sharpe_ratio()
# Out:
# 1.588681

# %%
test.sharpe_ratio(return_buy_hold=True)
# Out:
# 0.606183
