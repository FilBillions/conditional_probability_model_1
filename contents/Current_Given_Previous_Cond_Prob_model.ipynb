# %%
from datetime import date, timedelta
from conditional_probability_obj import Conditional_Probability
from current_given_previous_func import conditional_probability
from charts import comparison, visual, linear_regression, normal

# %% [raw]
# YYYY-MM-DD
# Yfinance universe inputs
# for current day: str(date.today() - timedelta(1))
# 2m, 5m, 15m, 30m :::: str(date.today() - timedelta(59))
# 60m, 90m, 1h  :::: str(date.today() - timedelta(729))
# 1d, 5d, 1wk, 1mo, 3mo :::: Any Start Date

# %%
universe = '2000-01-01'

# %%
test = Conditional_Probability("SPY", start = universe, end=str(date.today() - timedelta(1)), interval = "1d")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
#target_probability, start_date, end_date
test.run_algo(target_probability=.55, start_date="2007-01-09", end_date="2008-01-09", return_table=True)
# Out:
# Buys/Sells Action
# No Action        182
# Buy to Open       33
# Sell to Close     32
# Hold (Long)        4
# Name: count, dtype: int64
#                Close      High       Low      Open     Volume  Day Count  \
# Date
# 2007-01-10  100.0852  100.1064   99.2084   99.4064   72428000       1765
# 2007-01-11  100.5236  100.8489  100.0569  100.1135   54476800       1766
# 2007-01-12  101.2873  101.2873  100.4883  100.5166   55370600       1767
# 2007-01-16  101.0893  101.4287  100.9267  101.1671   44871300       1768
# 2007-01-17  101.1317  101.4428  100.9266  101.0115   50241400       1769
# ...              ...       ...       ...       ...        ...        ...
# 2008-01-02  104.3735  105.8570  103.6173  105.5257  204935600       2011
# 2008-01-03  104.3231  104.7768  103.7542  104.3591  125133300       2012
# 2008-01-04  101.7665  103.3004  101.4784  103.2284  232330900       2013
# 2008-01-07  101.6801  102.4290  100.8951  102.1266  234991000       2014
# 2008-01-08  100.0381  102.9116   99.6996  102.3210  326365700       2015
#
#             Return  Previous Close         Action  Probability > 0%  \
# Date
# 2007-01-10  0.3326         99.7529      No Action            0.5067
# 2007-01-11  0.4371        100.0852      No Action            0.5342
# 2007-01-12  0.7569        100.5236      No Action            0.5067
# 2007-01-16 -0.1957        101.2873      No Action            0.5067
# 2007-01-17  0.0419        101.0893      No Action            0.5067
# ...            ...             ...            ...               ...
# 2008-01-02 -0.8793        105.2953  Sell to Close            0.5452
# 2008-01-03 -0.0483        104.3735      No Action            0.5452
# 2008-01-04 -2.4812        104.3231      No Action            0.5452
# 2008-01-07 -0.0849        101.7665      No Action            0.5452
# 2008-01-08 -1.6280        101.6801    Buy to Open            0.5890
#
#             Buy Signal  Sell Signal
# Date
# 2007-01-10         NaN          NaN
# 2007-01-11         NaN          NaN
# 2007-01-12         NaN          NaN
# 2007-01-16         NaN          NaN
# 2007-01-17         NaN          NaN
# ...                ...          ...
# 2008-01-02         NaN     105.2953
# 2008-01-03         NaN          NaN
# 2008-01-04         NaN          NaN
# 2008-01-07         NaN          NaN
# 2008-01-08    101.6801          NaN
#
# [251 rows x 12 columns]

# %%
test.backtest(return_table=True)
# Out:
# SPY Buy/Hold Result: -0.05%
# SPY Model Result: 3.4%
#  from 2007-01-10 00:00:00 to 2008-01-08 00:00:00
#                  Close        High         Low        Open  Day Count  \
# Date
# 2007-01-10  100.085205  100.106428   99.208388   99.406380       1765
# 2007-01-11  100.523605  100.848873  100.056906  100.113477       1766
# 2007-01-12  101.287323  101.287323  100.488278  100.516558       1767
# 2007-01-16  101.089294  101.428707  100.926650  101.167078       1768
# 2007-01-17  101.131706  101.442839  100.926637  101.011498       1769
# ...                ...         ...         ...         ...        ...
# 2008-01-02  104.373474  105.857023  103.617310  105.525742       2011
# 2008-01-03  104.323105  104.776812  103.754179  104.359115       2012
# 2008-01-04  101.766472  103.300426  101.478410  103.228405       2013
# 2008-01-07  101.680077  102.429043  100.895100  102.126575       2014
# 2008-01-08  100.038124  102.911575   99.699646  102.321046       2015
#
#               Return  Previous Close         Action  Probability > 0%  \
# Date
# 2007-01-10  0.332575       99.752899      No Action          0.506667
# 2007-01-11  0.437071      100.085205      No Action          0.534173
# 2007-01-12  0.756868      100.523605      No Action          0.506667
# 2007-01-16 -0.195703      101.287323      No Action          0.506667
# 2007-01-17  0.041946      101.089294      No Action          0.506667
# ...              ...             ...            ...               ...
# 2008-01-02 -0.879332      105.295311  Sell to Close          0.545166
# 2008-01-03 -0.048270      104.373474      No Action          0.545166
# 2008-01-04 -2.481216      104.323105      No Action          0.545166
# 2008-01-07 -0.084932      101.766472      No Action          0.545166
# 2008-01-08 -1.628003      101.680077    Buy to Open          0.589041
#
#             Buy Signal  Sell Signal  Buy/Hold Value   Model Value
# Date
# 2007-01-10         NaN          NaN    10033.312907  10000.000000
# 2007-01-11         NaN          NaN    10077.261532  10000.000000
# 2007-01-12         NaN          NaN    10153.822479  10000.000000
# 2007-01-16         NaN          NaN    10133.970569  10000.000000
# 2007-01-17         NaN          NaN    10138.222255  10000.000000
# ...                ...          ...             ...           ...
# 2008-01-02         NaN   105.295311    10463.202071  10339.854823
# 2008-01-03         NaN          NaN    10458.152668  10339.854823
# 2008-01-04         NaN          NaN    10201.856057  10339.854823
# 2008-01-07         NaN          NaN    10193.195130  10339.854823
# 2008-01-08  101.680077          NaN    10028.593145  10339.854823
#
# [251 rows x 13 columns]

# %%
comparison(test)

# %%
test.sharpe_ratio()
# Out:
# 0.452076

# %%
test.sharpe_ratio(return_buy_hold=True)
# Out:
# 0.078054
