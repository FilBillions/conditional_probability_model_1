# %%
from datetime import date, timedelta
from stats_obj import Stats

# %%
# YYYY-MM-DD
# for current day: str(date.today() - timedelta(1))
# for 60 days ago for smaller timeframes: str(date.today() - timedelta(59))
# for 730 days ago for smaller timeframes: str(date.today() - timedelta(729))

# %%
test = Stats("SPY", start = "2005-05-08", end=str(date.today() - timedelta(1)), interval = "1wk")
test.normal_test()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# DescribeResult(nobs=1045, minmax=(-22.0, 12.0), mean=0.20095693779904306, variance=6.427010577645786, skewness=-1.0105505671176385, kurtosis=9.47860001010913)
# Null: The Sample is Normally Distributed
# If P-Value < .05: Reject H0; If P-Value >= .05: Cannot Reject H0
# ------------------------------------------------------------
# Random Test: Statistic: -0.61, P-Value: 0.54
# We cannot reject H0
# ------------------------------------------------------------
# SPY Test: Statistic: 13.72, P-Value: 0.0
# We can reject H0, this is probably not Normally Distributed

# %%
test.probability(threshold=-3)
# Out:
# Probability of SPY losing -3% in 1wk is 10.34%

# %%
test.visual()

# %%
test.conditional_probability()
# Out:
# ------------------------------------------------------------
# Top 5 Probabilities
# P(Negative | 1% to 2%) = 63.1944%
# P(Negative | >4%) = 61.7647%
# P(Positive | 2% to 3%) = 55.1724%
# P(Negative | 0% to 1%) = 54.5045%
# P(Negative | -1% to 0%) = 54.2735%
# ------------------------------------------------------------
# ------------------------------------------------------------
# Top 5 Worst Probabilities
# P(3% to 4% | 0% to 1%) = 0.4505%
# P(3% to 4% | 1% to 2%) = 0.6944%
# P(>4% | 1% to 2%) = 0.6944%
# P(>4% | 0% to 1%) = 1.3514%
# P(>3% | 1% to 2%) = 1.3889%
#                                Current 1wk Return                        \
#                                              <-4% -4% to -3% -3% to -2%
# Previous 1wk Return <-4%                    20.00       3.33       6.67
#                     -4% to -3%               4.76       7.14       4.76
#                     -3% to -2%               6.41       5.13       5.13
#                     -2% to -1%               8.78       6.08       7.43
#                     -1% to 0%                3.85       3.42       8.55
#                     0% to 1%                 1.80       2.25       6.76
#                     1% to 2%                 3.47       5.56       7.64
#                     2% to 3%                 1.72       0.00       5.17
#                     3% to 4%                 4.17       8.33      16.67
#                     >4%                     23.53       5.88      11.76
#
#                                                                        \
#                                -2% to -1% -1% to 0% 0% to 1% 1% to 2%
# Previous 1wk Return <-4%             8.33     10.00     8.33    11.67
#                     -4% to -3%      16.67     19.05     9.52     7.14
#                     -3% to -2%      14.10     20.51    15.38    11.54
#                     -2% to -1%      12.16     16.22    18.24    16.22
#                     -1% to 0%       13.25     25.21    23.93    15.38
#                     0% to 1%        15.32     28.38    23.42    16.22
#                     1% to 2%        17.36     29.17    24.31     8.33
#                     2% to 3%        18.97     18.97    27.59    20.69
#                     3% to 4%         4.17     12.50    41.67     8.33
#                     >4%             14.71      5.88    14.71     8.82
#
#                                                                            \
#                                2% to 3% 3% to 4%    >4% Negative Positive
# Previous 1wk Return <-4%           6.67     3.33  21.67    48.33    51.67
#                     -4% to -3%     9.52     9.52  11.90    52.38    47.62
#                     -3% to -2%    11.54     5.13   5.13    51.28    48.72
#                     -2% to -1%     9.46     3.38   2.03    50.68    49.32
#                     -1% to 0%      2.99     1.71   1.71    54.27    45.73
#                     0% to 1%       4.05     0.45   1.35    54.50    45.50
#                     1% to 2%       2.78     0.69   0.69    63.19    36.81
#                     2% to 3%       3.45     1.72   1.72    44.83    55.17
#                     3% to 4%       4.17     0.00   0.00    45.83    54.17
#                     >4%            8.82     5.88   0.00    61.76    38.24
#
#
#                                   >1%    >2%    >3%
# Previous 1wk Return <-4%        43.33  31.67  25.00
#                     -4% to -3%  38.10  30.95  21.43
#                     -3% to -2%  33.33  21.79  10.26
#                     -2% to -1%  31.08  14.86   5.41
#                     -1% to 0%   21.79   6.41   3.42
#                     0% to 1%    22.07   5.86   1.80
#                     1% to 2%    12.50   4.17   1.39
#                     2% to 3%    27.59   6.90   3.45
#                     3% to 4%    12.50   4.17   0.00
#                     >4%         23.53  14.71   5.88
