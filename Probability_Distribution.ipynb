# %%
from datetime import date, timedelta
from stats_obj import Stats

# %%
# YYYY-MM-DD
# for current day: str(date.today() - timedelta(1))
# for 60 days ago for smaller timeframes: str(date.today() - timedelta(59))
# for 730 days ago for smaller timeframes: str(date.today() - timedelta(729))

# %%
test = Stats("AMZN", start = "2015-05-08", end=str(date.today() - timedelta(1)), interval = "1d")
test.is_normal()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# DescribeResult(nobs=2521, minmax=(-15.14, 12.69), mean=0.08926219754065846, variance=4.279719137971201, skewness=0.004721451783840113, kurtosis=5.024622543496383)
# Null: The Sample is Normally Distributed
# If P-Value < .05: Reject H0; If P-Value >= .05: Cannot Reject H0
# ------------------------------------------------------------
# Random Test: Statistic: 1.71, P-Value: 0.09
# We cannot reject H0
# ------------------------------------------------------------
# AMZN Test: Statistic: 16.88, P-Value: 0.0
# We can reject H0, this is probably not Normally Distributed

# %%
test.probability(threshold=-3)
# Out:
# Probability of AMZN losing -3% in one day is 6.77%

# %%
test.visual()

# %%
test.linear_regression()
# Out:
# Linear Regression Model: [0.96928829 0.0310803 ]
