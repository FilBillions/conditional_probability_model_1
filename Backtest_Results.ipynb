# %% [markdown]
# # Backtest Results

# %%
from backtest import return_hist, sharpe_hist
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
return_hist('backtest_results.csv', both=True)
# Out:
# --------------------------------------------------
# n = 792
# --------------------------------------------------
# Model Results:
# Model Mean: 2.84%
# Model Std: 11.55%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 9.5%
# Buy/Hold Std: 16.34%
# --------------------------------------------------

# %%
sharpe_hist('backtest_results.csv', both=True)
# Out:
# --------------------------------------------------
# n = 792
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.5666
# Model Std: 1.0686
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.8323
# Buy/Hold Std: 0.9638
# --------------------------------------------------
