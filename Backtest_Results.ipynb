# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='SPY_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 744
# --------------------------------------------------
# Model Results:
# Model Mean: 2.21%
# Model Std: 12.9%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 9.84%
# Buy/Hold Std: 16.64%
# --------------------------------------------------

# %%
sharpe_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 744
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.5415
# Model Std: 1.0726
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.8297
# Buy/Hold Std: 0.943
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is down
# --------------------------------------------------
# --------------------------------------------------
# n = 163
# --------------------------------------------------
# Model Results:
# Model Mean: -5.99%
# Model Std: 18.39%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -14.65%
# Buy/Hold Std: 10.32%
# --------------------------------------------------
# --------------------------------------------------
# n = 163
# --------------------------------------------------
# Model Sharpe:
# Model Mean: -0.2165
# Model Std: 1.029
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: -0.5084
# Buy/Hold Std: 0.3508
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is up
# --------------------------------------------------
# --------------------------------------------------
# n = 581
# --------------------------------------------------
# Model Results:
# Model Mean: 4.51%
# Model Std: 9.72%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 16.71%
# Buy/Hold Std: 10.45%
# --------------------------------------------------
# --------------------------------------------------
# n = 581
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.7542
# Model Std: 0.9855
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 1.2051
# Buy/Hold Std: 0.6785
# --------------------------------------------------
