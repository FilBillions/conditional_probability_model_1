# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist

# %%
return_hist('SPY_backtest_results.csv',both=True)
# Out:
# --------------------------------------------------
# n = 5
# --------------------------------------------------
# Model Results:
# Model Mean: 3.45%
# Model Std: 6.9%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -3.04%
# Buy/Hold Std: 16.02%
# --------------------------------------------------
