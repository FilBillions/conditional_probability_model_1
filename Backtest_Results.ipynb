# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='NVDA_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 789
# --------------------------------------------------
# Model Results:
# Model Mean: 3.68%
# Model Std: 28.5%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 46.64%
# Buy/Hold Std: 78.4%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 8.67%
# SPY Buy/Hold Std: 16.93%
# --------------------------------------------------

# %%
sharpe_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 789
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.2418
# Model Std: 1.0306
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.8536
# Buy/Hold Std: 1.0995
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.7822
# SPY Std: 0.9702
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 118
# --------------------------------------------------
# Model Results:
# Model Mean: 16.27%
# Model Std: 38.39%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -50.51%
# Buy/Hold Std: 24.33%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: -19.09%
# SPY Buy/Hold Std: 10.17%
# --------------------------------------------------
# --------------------------------------------------
# n = 118
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.5785
# Model Std: 0.6712
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: -0.6827
# Buy/Hold Std: 0.5596
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: -0.6799
# SPY Std: 0.3264
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 472
# --------------------------------------------------
# Model Results:
# Model Mean: -2.29%
# Model Std: 22.42%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 89.29%
# Buy/Hold Std: 64.68%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 18.06%
# SPY Buy/Hold Std: 10.17%
# --------------------------------------------------
# --------------------------------------------------
# n = 472
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.1019
# Model Std: 1.0876
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 1.5456
# Buy/Hold Std: 0.68
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 1.3259
# SPY Std: 0.6879
# --------------------------------------------------
