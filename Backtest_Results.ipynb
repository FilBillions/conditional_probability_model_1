# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='SPY_1d_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 936
# --------------------------------------------------
# Model Results:
# Model Mean: 2.36%
# Model Std: 12.84%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 9.72%
# Buy/Hold Std: 16.59%
# --------------------------------------------------

# %%
sharpe_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 936
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.5651
# Model Std: 1.0628
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.836
# Buy/Hold Std: 0.9516
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is down
# --------------------------------------------------
# --------------------------------------------------
# n = 208
# --------------------------------------------------
# Model Results:
# Model Mean: -5.8%
# Model Std: 18.5%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -14.62%
# Buy/Hold Std: 10.42%
# --------------------------------------------------
# --------------------------------------------------
# n = 208
# --------------------------------------------------
# Model Sharpe:
# Model Mean: -0.1918
# Model Std: 1.0482
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: -0.5038
# Buy/Hold Std: 0.357
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is up
# --------------------------------------------------
# --------------------------------------------------
# n = 728
# --------------------------------------------------
# Model Results:
# Model Mean: 4.69%
# Model Std: 9.5%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 16.67%
# Buy/Hold Std: 10.25%
# --------------------------------------------------
# --------------------------------------------------
# n = 728
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.7814
# Model Std: 0.9639
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 1.2188
# Buy/Hold Std: 0.6841
# --------------------------------------------------
