# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='SPY_1d_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 1027
# --------------------------------------------------
# 90% Confidence Interval: (1.7345, 3.0621)
# 95% Confidence Interval: (1.6073, 3.1893)
# 98% Confidence Interval: (1.4594, 3.3372)
# 99% Confidence Interval: (1.4594, 3.3372)
# --------------------------------------------------
# Model Results:
# Model Mean: 2.4%
# Model Std: 12.93%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 9.76%
# Buy/Hold Std: 16.51%
# --------------------------------------------------

# %%
sharpe_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 1027
# --------------------------------------------------
# 90% Confidence Interval: (0.508, 0.6166)
# 95% Confidence Interval: (0.4976, 0.627)
# 98% Confidence Interval: (0.4855, 0.639)
# 99% Confidence Interval: (0.4855, 0.639)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.5623
# Model Std: 1.0576
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.838
# Buy/Hold Std: 0.9446
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is down
# --------------------------------------------------
# --------------------------------------------------
# n = 223
# --------------------------------------------------
# 90% Confidence Interval: (-8.2817, -4.0989)
# 95% Confidence Interval: (-8.6823, -3.6983)
# 98% Confidence Interval: (-9.1482, -3.2324)
# 99% Confidence Interval: (-9.1482, -3.2324)
# --------------------------------------------------
# Model Results:
# Model Mean: -6.19%
# Model Std: 18.99%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -14.8%
# Buy/Hold Std: 10.62%
# --------------------------------------------------
# --------------------------------------------------
# n = 223
# --------------------------------------------------
# 90% Confidence Interval: (-0.3281, -0.0927)
# 95% Confidence Interval: (-0.3507, -0.0702)
# 98% Confidence Interval: (-0.3769, -0.0439)
# 99% Confidence Interval: (-0.3769, -0.0439)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: -0.2104
# Model Std: 1.0687
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: -0.507
# Buy/Hold Std: 0.3595
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is up
# --------------------------------------------------
# --------------------------------------------------
# n = 804
# --------------------------------------------------
# 90% Confidence Interval: (4.2366, 5.3243)
# 95% Confidence Interval: (4.1324, 5.4285)
# 98% Confidence Interval: (4.0113, 5.5497)
# 99% Confidence Interval: (4.0113, 5.5497)
# --------------------------------------------------
# Model Results:
# Model Mean: 4.78%
# Model Std: 9.38%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 16.57%
# Buy/Hold Std: 10.16%
# --------------------------------------------------
# --------------------------------------------------
# n = 804
# --------------------------------------------------
# 90% Confidence Interval: (0.7215, 0.8317)
# 95% Confidence Interval: (0.711, 0.8422)
# 98% Confidence Interval: (0.6987, 0.8545)
# 99% Confidence Interval: (0.6987, 0.8545)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.7766
# Model Std: 0.9496
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 1.2111
# Buy/Hold Std: 0.6802
# --------------------------------------------------
